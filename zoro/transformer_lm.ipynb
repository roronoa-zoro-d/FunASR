# %%
import sys

sys.path.append('/home/zhangjiayuan/program/audio/asr/modelscope/FunASR/funasr/')

from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

inference_pipline = pipeline(
    task=Tasks.language_score_prediction,
    model='damo/speech_transformer_lm_zh-cn-common-vocab8404-pytorch',
    output_dir='./tmp/')

rec_result = inference_pipline(text_in='hello 大 家 好 呀')
print(rec_result)
# Out:
# Downloading Model to directory: /home/zhangjiayuan/.cache/modelscope/hub/damo/speech_transformer_lm_zh-cn-common-vocab8404-pytorch
# 2025-01-15 01:47:01,348 - modelscope - WARNING - Model revision not specified, use revision: v0.2.2
# 2025-01-15 01:47:01,694 - modelscope - WARNING - ('PIPELINES', 'language-score-prediction', 'language-score-prediction') not found in ast index file
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 8
#       5 from modelscope.pipelines import pipeline
#       6 from modelscope.utils.constant import Tasks
# ----> 8 inference_pipline = pipeline(
#       9     task=Tasks.language_score_prediction,
#      10     model='damo/speech_transformer_lm_zh-cn-common-vocab8404-pytorch',
#      11     output_dir='./tmp/')
#      13 rec_result = inference_pipline(text_in='hello 大 家 好 呀')
#      14 print(rec_result)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/builder.py:180, in pipeline(task, model, preprocessor, config_file, pipeline_name, framework, device, model_revision, ignore_file_pattern, **kwargs)
#     177 if preprocessor is not None:
#     178     cfg.preprocessor = preprocessor
# --> 180 return build_pipeline(cfg, task_name=task)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/builder.py:65, in build_pipeline(cfg, task_name, default_args)
#      54 def build_pipeline(cfg: ConfigDict,
#      55                    task_name: str = None,
#      56                    default_args: dict = None):
#      57     """ build pipeline given model config dict.
#      58
#      59     Args:
#    (...)
#      63         default_args (dict, optional): Default initialization arguments.
#      64     """
# ---> 65     return build_from_cfg(
#      66         cfg, PIPELINES, group_key=task_name, default_args=default_args)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:197, in build_from_cfg(cfg, registry, group_key, default_args)
#     195     obj_cls = registry.get(obj_type, group_key=group_key)
#     196     if obj_cls is None:
# --> 197         raise KeyError(
#     198             f'{obj_type} is not in the {registry.name}'
#     199             f' registry group {group_key}. Please make'
#     200             f' sure the correct version of ModelScope library is used.')
#     201     obj_cls.group_key = group_key
#     202 elif inspect.isclass(obj_type) or inspect.isfunction(obj_type):
#
# KeyError: 'language-score-prediction is not in the pipelines registry group language-score-prediction. Please make sure the correct version of ModelScope library is used.'
