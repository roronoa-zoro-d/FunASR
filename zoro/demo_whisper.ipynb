# %%
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

inference_pipeline = pipeline(
    task=Tasks.auto_speech_recognition,
    model='iic/Whisper-large-v3', model_revision="v2.0.5")

rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav', language=None, disable_update=True)
print(rec_result)
# Out:
# Downloading Model to directory: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3
# 2025-03-07 02:58:42,890 - modelscope - INFO - Use user-specified model revision: v2.0.5
# 2025-03-07 02:58:43,125 - modelscope - INFO - initiate model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3
# 2025-03-07 02:58:43,126 - modelscope - INFO - initiate model from location /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3.
# 2025-03-07 02:58:43,130 - modelscope - INFO - initialize model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3
# funasr version: 1.2.2.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# New version is available: 1.2.4.
# Please use the command "pip install -U funasr" to upgrade.
# Detect model requirements, begin to install it: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3/requirements.txt
# install model requirements successfully
# 2025-03-07 02:59:20,419 - modelscope - WARNING - No preprocessor field found in cfg.
# 2025-03-07 02:59:20,420 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2025-03-07 02:59:20,421 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3'}. trying to build by task and model information.
# 2025-03-07 02:59:20,422 - modelscope - WARNING - No preprocessor key ('funasr', 'auto-speech-recognition') found in PREPROCESSOR_MAP, skip building preprocessor.
# rtf_avg: 0.241: 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# [{'key': 'asr_example_zh', 'text': '欢迎大家来体验达摩院推出的语音识别模型'}]

# %%
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

inference_pipeline = pipeline(
    task=Tasks.auto_speech_recognition,
    model='iic/Whisper-large-v3-turbo', model_revision="master")

rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav', language=None)
print(rec_result)
# Out:
# Downloading Model to directory: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo
# 2025-03-07 02:57:41,654 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# 2025-03-07 02:57:41,944 - modelscope - INFO - initiate model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo
# 2025-03-07 02:57:41,946 - modelscope - INFO - initiate model from location /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo.
# 2025-03-07 02:57:41,949 - modelscope - INFO - initialize model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo
# funasr version: 1.2.2.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# New version is available: 1.2.4.
# Please use the command "pip install -U funasr" to upgrade.
# Detect model requirements, begin to install it: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo/requirements.txt
# install model requirements successfully
# 2025-03-07 02:58:10,629 - modelscope - WARNING - No preprocessor field found in cfg.
# 2025-03-07 02:58:10,634 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2025-03-07 02:58:10,635 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': '/home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo'}. trying to build by task and model information.
# 2025-03-07 02:58:10,636 - modelscope - WARNING - No preprocessor key ('funasr', 'auto-speech-recognition') found in PREPROCESSOR_MAP, skip building preprocessor.
# rtf_avg: 0.116: 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]
# [{'key': 'asr_example_zh', 'text': '欢迎大家来体验达摩院推出的语音识别模型'}]
