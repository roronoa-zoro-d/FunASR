# %%
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

inference_pipeline = pipeline(
    task=Tasks.auto_speech_recognition,
    model='iic/Whisper-large-v3', model_revision="v2.0.5")

rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav', language=None)
print(rec_result)
# Out:
# Downloading Model to directory: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3
# 2025-02-10 01:38:14,662 - modelscope - INFO - Use user-specified model revision: v2.0.5
# 2025-02-10 01:38:14,942 - modelscope - INFO - initiate model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3
# 2025-02-10 01:38:14,943 - modelscope - INFO - initiate model from location /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3.
# 2025-02-10 01:38:14,945 - modelscope - INFO - initialize model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3
# funasr version: 1.2.2.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# New version is available: 1.2.3.
# Please use the command "pip install -U funasr" to upgrade.
# Detect model requirements, begin to install it: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3/requirements.txt
# install model requirements successfully
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:209, in build_from_cfg(cfg, registry, group_key, default_args)
#     208 if hasattr(obj_cls, '_instantiate'):
# --> 209     return obj_cls._instantiate(**args)
#     210 else:
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/base/base_model.py:67, in Model._instantiate(cls, **kwargs)
#      62 """ Define the instantiation method of a model,default method is by
#      63     calling the constructor. Note that in the case of no loading model
#      64     process in constructor of a task model, a load_model method is
#      65     added, and thus this method is overloaded
#      66 """
# ---> 67 return cls(**kwargs)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/audio/funasr/model.py:55, in GenericFunASR.__init__(self, model_dir, *args, **kwargs)
#      52     kwargs['spk_model_revision'] = model_cfg.get(
#      53         'spk_model_revision', None)
# ---> 55 self.model = AutoModel(model=model_dir, **kwargs)
#
# File ~/program/audio/asr/modelscope/FunASR-Zoro/funasr/auto/auto_model.py:125, in AutoModel.__init__(self, **kwargs)
#     123 logging.basicConfig(level=log_level)
# --> 125 model, kwargs = self.build_model(**kwargs)
#     127 # if vad_model is not None, build vad model else None
#
# File ~/program/audio/asr/modelscope/FunASR-Zoro/funasr/auto/auto_model.py:259, in AutoModel.build_model(**kwargs)
#     258 model_class = tables.model_classes.get(kwargs["model"])
# --> 259 assert model_class is not None, f'{kwargs["model"]} is not registered'
#     260 model_conf = {}
#
# AssertionError: WhisperWarp is not registered
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:211, in build_from_cfg(cfg, registry, group_key, default_args)
#     210     else:
# --> 211         return obj_cls(**args)
#     212 except Exception as e:
#     213     # Normal TypeError does not print class name.
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/audio/funasr_pipeline.py:62, in FunASRPipeline.__init__(self, model, **kwargs)
#      60 """use `model` to create an vad pipeline for prediction
#      61 """
# ---> 62 super().__init__(model=model, **kwargs)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/base.py:100, in Pipeline.__init__(self, config_file, model, preprocessor, device, auto_collate, device_map, **kwargs)
#      99 if not isinstance(model, List):
# --> 100     self.model = self.initiate_single_model(model, **kwargs)
#     101     self.models = [self.model]
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/base.py:53, in Pipeline.initiate_single_model(self, model, **kwargs)
#      52     # expecting model has been prefetched to local cache beforehand
# ---> 53     return Model.from_pretrained(
#      54         model,
#      55         device=self.device_name,
#      56         model_prefetched=True,
#      57         invoked_by=Invoke.PIPELINE,
#      58         device_map=self.device_map,
#      59         **kwargs) if is_model(model) else model
#      60 else:
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/base/base_model.py:183, in Model.from_pretrained(cls, model_name_or_path, revision, cfg_dict, device, **kwargs)
#     182 else:
# --> 183     model = build_model(model_cfg, task_name=task_name)
#     185 # dynamically add pipeline info to model for pipeline inference
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/builder.py:35, in build_model(cfg, task_name, default_args)
#      34 try:
# ---> 35     model = build_from_cfg(
#      36         cfg, MODELS, group_key=task_name, default_args=default_args)
#      37 except KeyError as e:
#      38     # Handle subtask with a backbone model that hasn't been registered
#      39     # All the subtask with a parent task should have a task model, otherwise it is not a
#      40     # valid subtask
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:214, in build_from_cfg(cfg, registry, group_key, default_args)
#     212 except Exception as e:
#     213     # Normal TypeError does not print class name.
# --> 214     raise type(e)(f'{obj_cls.__name__}: {e}')
#
# AssertionError: GenericFunASR: WhisperWarp is not registered
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 from modelscope.pipelines import pipeline
#       2 from modelscope.utils.constant import Tasks
# ----> 4 inference_pipeline = pipeline(
#       5     task=Tasks.auto_speech_recognition,
#       6     model='iic/Whisper-large-v3', model_revision="v2.0.5")
#       8 rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav', language=None)
#       9 print(rec_result)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/builder.py:180, in pipeline(task, model, preprocessor, config_file, pipeline_name, framework, device, model_revision, ignore_file_pattern, **kwargs)
#     177 if preprocessor is not None:
#     178     cfg.preprocessor = preprocessor
# --> 180 return build_pipeline(cfg, task_name=task)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/builder.py:65, in build_pipeline(cfg, task_name, default_args)
#      54 def build_pipeline(cfg: ConfigDict,
#      55                    task_name: str = None,
#      56                    default_args: dict = None):
#      57     """ build pipeline given model config dict.
#      58
#      59     Args:
#    (...)
#      63         default_args (dict, optional): Default initialization arguments.
#      64     """
# ---> 65     return build_from_cfg(
#      66         cfg, PIPELINES, group_key=task_name, default_args=default_args)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:214, in build_from_cfg(cfg, registry, group_key, default_args)
#     211         return obj_cls(**args)
#     212 except Exception as e:
#     213     # Normal TypeError does not print class name.
# --> 214     raise type(e)(f'{obj_cls.__name__}: {e}')
#
# AssertionError: FunASRPipeline: GenericFunASR: WhisperWarp is not registered

# %%
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

inference_pipeline = pipeline(
    task=Tasks.auto_speech_recognition,
    model='iic/Whisper-large-v3-turbo', model_revision="master")

rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav', language=None)
print(rec_result)
# Out:
# Downloading Model to directory: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo
# 2025-02-10 01:51:58,449 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# 2025-02-10 01:51:58,718 - modelscope - INFO - Got 6 files, start to download ...
# Processing 6 items:   0%|          | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading [config.yaml]: 100%|██████████| 708/708 [00:00<00:00, 2.40kB/s]
# Processing 6 items:  17%|█▋        | 1/6 [00:00<00:01,  3.14it/s]
#
#
#
#
# Downloading [requirements.txt]: 100%|██████████| 24.0/24.0 [00:00<00:00, 82.4B/s]
#
#
#
# Downloading [README.md]: 100%|██████████| 10.2k/10.2k [00:00<00:00, 33.5kB/s]
#
#
# Downloading [configuration.json]: 100%|██████████| 285/285 [00:00<00:00, 803B/s]
# Downloading [example/asr_example.wav]: 100%|██████████| 173k/173k [00:00<00:00, 397kB/s]
# Processing 6 items:  83%|████████▎ | 5/6 [00:00<00:00, 12.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing 6 items:  83%|████████▎ | 5/6 [00:14<00:00, 12.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading [large-v3-turbo.pt]: 100%|██████████| 1.51G/1.51G [01:26<00:00, 18.7MB/s]
# Processing 6 items: 100%|██████████| 6/6 [01:26<00:00, 14.45s/it]
# 2025-02-10 01:53:25,429 - modelscope - INFO - Download model 'iic/Whisper-large-v3-turbo' successfully.
# 2025-02-10 01:53:25,436 - modelscope - INFO - initiate model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo
# 2025-02-10 01:53:25,437 - modelscope - INFO - initiate model from location /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo.
# 2025-02-10 01:53:25,440 - modelscope - INFO - initialize model from /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo
# funasr version: 1.2.2.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# New version is available: 1.2.3.
# Please use the command "pip install -U funasr" to upgrade.
# Detect model requirements, begin to install it: /home/zhangjiayuan/.cache/modelscope/hub/iic/Whisper-large-v3-turbo/requirements.txt
# install model requirements successfully
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:209, in build_from_cfg(cfg, registry, group_key, default_args)
#     208 if hasattr(obj_cls, '_instantiate'):
# --> 209     return obj_cls._instantiate(**args)
#     210 else:
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/base/base_model.py:67, in Model._instantiate(cls, **kwargs)
#      62 """ Define the instantiation method of a model,default method is by
#      63     calling the constructor. Note that in the case of no loading model
#      64     process in constructor of a task model, a load_model method is
#      65     added, and thus this method is overloaded
#      66 """
# ---> 67 return cls(**kwargs)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/audio/funasr/model.py:55, in GenericFunASR.__init__(self, model_dir, *args, **kwargs)
#      52     kwargs['spk_model_revision'] = model_cfg.get(
#      53         'spk_model_revision', None)
# ---> 55 self.model = AutoModel(model=model_dir, **kwargs)
#
# File ~/program/audio/asr/modelscope/FunASR-Zoro/funasr/auto/auto_model.py:125, in AutoModel.__init__(self, **kwargs)
#     123 logging.basicConfig(level=log_level)
# --> 125 model, kwargs = self.build_model(**kwargs)
#     127 # if vad_model is not None, build vad model else None
#
# File ~/program/audio/asr/modelscope/FunASR-Zoro/funasr/auto/auto_model.py:259, in AutoModel.build_model(**kwargs)
#     258 model_class = tables.model_classes.get(kwargs["model"])
# --> 259 assert model_class is not None, f'{kwargs["model"]} is not registered'
#     260 model_conf = {}
#
# AssertionError: WhisperWarp is not registered
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:211, in build_from_cfg(cfg, registry, group_key, default_args)
#     210     else:
# --> 211         return obj_cls(**args)
#     212 except Exception as e:
#     213     # Normal TypeError does not print class name.
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/audio/funasr_pipeline.py:62, in FunASRPipeline.__init__(self, model, **kwargs)
#      60 """use `model` to create an vad pipeline for prediction
#      61 """
# ---> 62 super().__init__(model=model, **kwargs)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/base.py:100, in Pipeline.__init__(self, config_file, model, preprocessor, device, auto_collate, device_map, **kwargs)
#      99 if not isinstance(model, List):
# --> 100     self.model = self.initiate_single_model(model, **kwargs)
#     101     self.models = [self.model]
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/base.py:53, in Pipeline.initiate_single_model(self, model, **kwargs)
#      52     # expecting model has been prefetched to local cache beforehand
# ---> 53     return Model.from_pretrained(
#      54         model,
#      55         device=self.device_name,
#      56         model_prefetched=True,
#      57         invoked_by=Invoke.PIPELINE,
#      58         device_map=self.device_map,
#      59         **kwargs) if is_model(model) else model
#      60 else:
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/base/base_model.py:183, in Model.from_pretrained(cls, model_name_or_path, revision, cfg_dict, device, **kwargs)
#     182 else:
# --> 183     model = build_model(model_cfg, task_name=task_name)
#     185 # dynamically add pipeline info to model for pipeline inference
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/models/builder.py:35, in build_model(cfg, task_name, default_args)
#      34 try:
# ---> 35     model = build_from_cfg(
#      36         cfg, MODELS, group_key=task_name, default_args=default_args)
#      37 except KeyError as e:
#      38     # Handle subtask with a backbone model that hasn't been registered
#      39     # All the subtask with a parent task should have a task model, otherwise it is not a
#      40     # valid subtask
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:214, in build_from_cfg(cfg, registry, group_key, default_args)
#     212 except Exception as e:
#     213     # Normal TypeError does not print class name.
# --> 214     raise type(e)(f'{obj_cls.__name__}: {e}')
#
# AssertionError: GenericFunASR: WhisperWarp is not registered
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 from modelscope.pipelines import pipeline
#       2 from modelscope.utils.constant import Tasks
# ----> 4 inference_pipeline = pipeline(
#       5     task=Tasks.auto_speech_recognition,
#       6     model='iic/Whisper-large-v3-turbo', model_revision="master")
#       8 rec_result = inference_pipeline(input='https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ASR/test_audio/asr_example_zh.wav', language=None)
#       9 print(rec_result)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/builder.py:180, in pipeline(task, model, preprocessor, config_file, pipeline_name, framework, device, model_revision, ignore_file_pattern, **kwargs)
#     177 if preprocessor is not None:
#     178     cfg.preprocessor = preprocessor
# --> 180 return build_pipeline(cfg, task_name=task)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/pipelines/builder.py:65, in build_pipeline(cfg, task_name, default_args)
#      54 def build_pipeline(cfg: ConfigDict,
#      55                    task_name: str = None,
#      56                    default_args: dict = None):
#      57     """ build pipeline given model config dict.
#      58
#      59     Args:
#    (...)
#      63         default_args (dict, optional): Default initialization arguments.
#      64     """
# ---> 65     return build_from_cfg(
#      66         cfg, PIPELINES, group_key=task_name, default_args=default_args)
#
# File ~/miniconda3/envs/ali_modelscope/lib/python3.8/site-packages/modelscope/utils/registry.py:214, in build_from_cfg(cfg, registry, group_key, default_args)
#     211         return obj_cls(**args)
#     212 except Exception as e:
#     213     # Normal TypeError does not print class name.
# --> 214     raise type(e)(f'{obj_cls.__name__}: {e}')
#
# AssertionError: FunASRPipeline: GenericFunASR: WhisperWarp is not registered
